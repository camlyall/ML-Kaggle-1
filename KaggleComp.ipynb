# %% [markdown]
# # Kaggle Competition

# %%
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# ## Training Data
# 456 labelled training data (268 of snowy scenes and 188 of not snowy scenes).

# %%
train_df = pd.read_csv("training.csv", delimiter=",", header=0)
train_df[0:1]
# Out:
#    ID     CNNs  CNNs.1  CNNs.2  CNNs.3  CNNs.4   CNNs.5  CNNs.6  CNNs.7  \
# 0   1  0.44918     0.0     0.0     0.0     0.0  0.11052   1.317     0.0
#
#    CNNs.8     ...      GIST.503  GIST.504  GIST.505  GIST.506  GIST.507  \
# 0  1.4343     ...      0.005435  0.002507  0.037413  0.047131  0.004175
#
#    GIST.508  GIST.509  GIST.510  GIST.511  prediction
# 0  0.003744  0.037672  0.071448  0.013265           1
#
# [1 rows x 4610 columns]

# %% [markdown]
# ## Testing Data
# 5040 of test data, which are not labelled.

# %%
test_df = pd.read_csv("testing.csv", delimiter=",", header=0)
test_df[0:1]
# Out:
#    ID    CNNs  CNNs.1  CNNs.2  CNNs.3   CNNs.4  CNNs.5  CNNs.6    CNNs.7  \
# 0   1  0.3945     0.0     0.0     0.0  0.71368     0.0     0.0  0.088419
#
#    CNNs.8    ...     GIST.502  GIST.503  GIST.504  GIST.505  GIST.506  \
# 0     0.0    ...     0.046335  0.059068  0.015266  0.026326  0.069981
#
#    GIST.507  GIST.508  GIST.509  GIST.510  GIST.511
# 0  0.082463   0.01685  0.026402  0.057077  0.018346
#
# [1 rows x 4609 columns]

# %% [markdown]
# ## Annotation Confidence
# Confidence of the label annotation for each training data point
# (456 labelled training data and additional but incomplete 4104 labelled training data).

# %%
confidence_df = pd.read_csv("annotation_confidence.csv", delimiter=",", header=0)
confidence_df[0:1]
# Out:
#    ID  confidence
# 0   1         1.0

# %% [markdown]
# ## Additional Training
# Additional 4104 labelled training data which is incomplete as it has missing feature values

# %%
additional_df = pd.read_csv("additional_training.csv", delimiter=",", header=0)
additional_df[0:1]
# Out:
#     ID  CNNs  CNNs.1  CNNs.2  CNNs.3  CNNs.4  CNNs.5  CNNs.6  CNNs.7  CNNs.8  \
# 0  457   NaN  1.7263     NaN     0.0     0.0   0.799     0.0     0.0     0.0
#
#       ...      GIST.503  GIST.504  GIST.505  GIST.506  GIST.507  GIST.508  \
# 0     ...           NaN  0.022648  0.043312  0.025739   0.02818  0.032245
#
#    GIST.509  GIST.510  GIST.511  prediction
# 0  0.036754  0.029104       NaN           1
#
# [1 rows x 4610 columns]

# %% [markdown]
# ## Test Proportions
# The proportion of positive (snowy) data points and the proportion of not snowy data points in the test set.

# %%
proportions_df = pd.read_csv("test_proportions.csv", delimiter=",", header=None, dtype="unicode")
proportions_df
# Out:
#                 0
# 0  0.4286 class 1
# 1  0.5714 class 0

# %% [markdown]
# # Attempt

# %% [markdown]
# ## Retrieve confident average
# * DF: Confident predictions
# * DF0: Confident 0
# * DF1: Confident 1
# * Arr: Averages

# %% [markdown]
# ### Sort values

# %%
# df.sort_values('colname', axis=0, ascending=False)

# %% [markdown]
# ## Clean

# %% [markdown]
# ## Create confident DataFrames for 0 and 1 predictions

# %%
r = 2
print("Training Data")
display(train_df[0:r])
print("Confidence Data")
display(confidence_df[0:r])

# print("Confident predictions ID")
c_df = confidence_df[confidence_df.confidence == 1]
confident_ids = confidence_df[confidence_df.confidence == 1].loc[c_df.ID].index.values.tolist()
# print(confident_ids[:r])

print("Confident predictions")
confident_train_df = train_df[train_df['ID'].isin(confident_ids)]
display(confident_train_df[:r])

print("Confident 0 predictions")
print("Confident 1 predictions")
confident_train_0_df = confident_train_df[(confident_train_df.prediction == 0)]
confident_train_1_df = confident_train_df[(confident_train_df.prediction == 1)]
display(confident_train_0_df[:r])
display(confident_train_1_df[:r])
# Out:
# Training Data
#    ID     CNNs  CNNs.1  CNNs.2  CNNs.3  CNNs.4   CNNs.5  CNNs.6  CNNs.7  \
# 0   1  0.44918     0.0     0.0     0.0     0.0  0.11052   1.317  0.0000
# 1   2  0.00000     0.0     0.0     0.0     0.0  0.63184   0.000  1.8388
#
#    CNNs.8     ...      GIST.503  GIST.504  GIST.505  GIST.506  GIST.507  \
# 0  1.4343     ...      0.005435  0.002507  0.037413  0.047131  0.004175
# 1  0.4959     ...      0.033147  0.008112  0.004126  0.014677  0.048980
#
#    GIST.508  GIST.509  GIST.510  GIST.511  prediction
# 0  0.003744  0.037672  0.071448  0.013265           1
# 1  0.011394  0.012629  0.033668  0.048248           1
#
# [2 rows x 4610 columns]
# Confidence Data
#    ID  confidence
# 0   1        1.00
# 1   2        0.66
# Confident predictions
#    ID     CNNs  CNNs.1  CNNs.2   CNNs.3  CNNs.4   CNNs.5    CNNs.6  CNNs.7  \
# 0   1  0.44918     0.0     0.0  0.00000     0.0  0.11052  1.317000  0.0000
# ...

# %% [markdown]
# ## Calculate averages of confident 0 and 1 predictions

# %%
print("Confident 0 Averages")
print("Confident 1 Averages")
confident_train_0_avg = pd.DataFrame(confident_train_0_df.mean(axis=0)[1:-1]).T
confident_train_1_avg = pd.DataFrame(confident_train_1_df.mean(axis=0)[1:-1]).T
display(confident_train_0_avg)
display(confident_train_1_avg)
# Out:
# Confident 0 Averages
# Confident 1 Averages
#        CNNs    CNNs.1    CNNs.2    CNNs.3    CNNs.4    CNNs.5    CNNs.6  \
# 0  0.215292  0.339621  0.183216  0.097272  0.254131  0.066736  0.155396
#
#      CNNs.7  CNNs.8    CNNs.9    ...     GIST.502  GIST.503  GIST.504  \
# 0  0.129293  0.0779  0.375786    ...     0.036616  0.027793  0.027661
#
#    GIST.505  GIST.506  GIST.507  GIST.508  GIST.509  GIST.510  GIST.511
# 0  0.037078  0.033417  0.027121  0.029276  0.038444  0.036219   0.02656
#
# [1 rows x 4608 columns]
#        CNNs    CNNs.1    CNNs.2  CNNs.3    CNNs.4    CNNs.5    CNNs.6  \
# 0  0.103416  0.181478  0.023226  0.1279  0.080345  0.224387  0.312417
#
#      CNNs.7    CNNs.8    CNNs.9    ...     GIST.502  GIST.503  GIST.504  \
# 0  0.351748  0.281232  0.272855    ...     0.028806  0.021864  0.021611
#
#    GIST.505  GIST.506  GIST.507  GIST.508  GIST.509  GIST.510  GIST.511
# 0  0.031417  0.029565  0.021452  0.023752      0.03  0.029956  0.024447
#
# ...

# %% [markdown]
# ## Create non-confident DataFrames for 0 and 1 predictions

# %%
non_confident_train_df = train_df[~train_df['ID'].isin(confident_ids)]
non_confident_train_0_df = non_confident_train_df[(non_confident_train_df.prediction == 0)]
non_confident_train_1_df = non_confident_train_df[(non_confident_train_df.prediction == 1)]
display(non_confident_train_df[:4])
display(non_confident_add_0_df)

# %%
print("Additional Data")
display(additional_df[:r])

print("Confident Additional Data")
confident_additional_df = additional_df[additional_df['ID'].isin(confident_ids)]
display(confident_additional_df[:r])

print("Confident 0 Additional Data - not needed")
confident_additional_0_df = confident_additional_df[confident_additional_df['prediction']==0]
##display(confident_additional_0_df[:r])

print("Confident 1 Additional Data - not needed")
confident_additional_1_df = confident_additional_df[confident_additional_df['prediction']==1]
##display(confident_additional_1_df[:r])
# Out:
# Additional Data
#     ID     CNNs  CNNs.1   CNNs.2   CNNs.3  CNNs.4   CNNs.5  CNNs.6   CNNs.7  \
# 0  457      NaN  1.7263      NaN  0.00000     0.0  0.79900  0.0000  0.00000
# 1  458  0.83494  0.0000  0.87363  0.18423     NaN  0.35443  1.2575  0.84533
#
#    CNNs.8     ...      GIST.503  GIST.504  GIST.505  GIST.506  GIST.507  \
# 0  0.0000     ...           NaN  0.022648  0.043312  0.025739   0.02818
# 1  0.8482     ...      0.005451       NaN  0.016365  0.014265       NaN
#
#    GIST.508  GIST.509  GIST.510  GIST.511  prediction
# 0  0.032245  0.036754  0.029104       NaN           1
# 1  0.026452       NaN  0.053096  0.057367           0
#
# [2 rows x 4610 columns]
# Confident Additional Data
#     ID  CNNs  CNNs.1  CNNs.2  CNNs.3  CNNs.4  CNNs.5  CNNs.6   CNNs.7  CNNs.8  \
# 0  457   NaN  1.7263     NaN     0.0     0.0   0.799     0.0  0.00000  0.0000
# 2  459   NaN     NaN     0.0     0.0     NaN   0.000     NaN  0.71016  0.5472
#
# ...

# %%
print("All rows with null first col")
confident_additional_df.loc[confident_additional_df.CNNs.isnull()][:r]
# Out:
# All rows with null first col
#     ID  CNNs  CNNs.1  CNNs.2  CNNs.3  CNNs.4  CNNs.5  CNNs.6   CNNs.7  CNNs.8  \
# 0  457   NaN  1.7263     NaN     0.0     0.0   0.799     0.0  0.00000  0.0000
# 2  459   NaN     NaN     0.0     0.0     NaN   0.000     NaN  0.71016  0.5472
#
#       ...      GIST.503  GIST.504  GIST.505  GIST.506  GIST.507  GIST.508  \
# 0     ...           NaN  0.022648  0.043312  0.025739  0.028180  0.032245
# 2     ...      0.008683       NaN  0.015751  0.005463  0.005901  0.018561
#
#    GIST.509  GIST.510  GIST.511  prediction
# 0  0.036754  0.029104       NaN           1
# 2  0.025340  0.005856  0.003299           1
#
# [2 rows x 4610 columns]

# %%
# Dont run i think...

newdf = pd.DataFrame(confident_additional_df.iloc[:,1:7].copy())
print("0")
display(newdf[:3])
print("1")
display(newdf.iloc)
newdf.iloc[:,0:2].fillna(avg)
display(newdf[:3])
print("2")
display(confident_additional_df[:3])

# %% [markdown]
# ## Replace confident 0 and 1 DFs Nan with Average from training confident 0 and 1s

# %%
ca0_d = confident_additional_0_df.drop(['ID', 'prediction'],axis=1).copy()
c0_avg = confident_0_avg.copy()
display(ca0_d[:3])
display(c0_avg)
for column in ca0_d:
    #print(c0_avg[[column]])
    #display(c0_avg.iloc[0][column])
    #ca_d.iloc[[column]].fillna(c0_avg.iloc[0][column])
    ca0_d[[column]] = ca0_d[[column]].fillna(value=c0_avg.iloc[0][column])
display(ca0_d[:3])
# Out:
#         CNNs   CNNs.1    CNNs.2   CNNs.3   CNNs.4  CNNs.5   CNNs.6    CNNs.7  \
# 5   0.000000  0.00000  0.041689  0.44601  0.00000     NaN  0.22815  0.021538
# 6   0.000000  0.14695       NaN  0.00000  1.41480  1.7356  0.00000  0.057167
# 26  0.028981      NaN  0.000000  0.00000  0.45042  0.0000  0.00000  0.000000
#
#     CNNs.8  CNNs.9    ...     GIST.502  GIST.503  GIST.504  GIST.505  \
# 5      0.0     NaN    ...     0.049250  0.017483  0.017380  0.038310
# 6      0.0  0.0000    ...          NaN  0.004572  0.003766  0.018723
# 26     NaN  1.7191    ...     0.065472  0.054324  0.059546  0.061372
#
#     GIST.506  GIST.507  GIST.508  GIST.509  GIST.510  GIST.511
# 5   0.054242  0.054469  0.012272  0.011186  0.046882  0.042986
# 6        NaN  0.012496  0.007650  0.006387  0.004385       NaN
# 26  0.042630  0.023522  0.069031       NaN  0.016562  0.014903
#
# [3 rows x 4608 columns]
#        CNNs    CNNs.1    CNNs.2    CNNs.3    CNNs.4    CNNs.5    CNNs.6  \
# ...

# %%
ca1_d = confident_additional_1_df.drop(['ID', 'prediction'],axis=1).copy()
c1_avg = confident_1_avg.copy()
display(ca1_d[:3])
display(c1_avg)
for column in ca1_d:
    #print(c1_avg[[column]])
    #display(c1_avg.iloc[0][column])
    #ca_d.iloc[[column]].fillna(c1_avg.iloc[0][column])
    ca1_d[[column]] = ca1_d[[column]].fillna(value=c1_avg.iloc[0][column])
display(ca1_d[:3])
# Out:
#    CNNs   CNNs.1  CNNs.2  CNNs.3   CNNs.4  CNNs.5   CNNs.6   CNNs.7   CNNs.8  \
# 0   NaN  1.72630     NaN     0.0  0.00000   0.799  0.00000  0.00000  0.00000
# 2   NaN      NaN     0.0     0.0      NaN   0.000      NaN  0.71016  0.54720
# 3   NaN  0.58965     NaN     0.0  0.25197   0.000  0.80329  0.00000  0.23879
#
#     CNNs.9    ...     GIST.502  GIST.503  GIST.504  GIST.505  GIST.506  \
# 0  0.00000    ...     0.027248       NaN  0.022648  0.043312  0.025739
# 2  0.48071    ...     0.012577  0.008683       NaN  0.015751  0.005463
# 3      NaN    ...          NaN  0.028226  0.004367  0.013654  0.036700
#
#    GIST.507  GIST.508  GIST.509  GIST.510  GIST.511
# 0  0.028180  0.032245  0.036754  0.029104       NaN
# 2  0.005901  0.018561  0.025340  0.005856  0.003299
# 3  0.029672  0.009894  0.005218  0.037673  0.031507
#
# [3 rows x 4608 columns]
#        CNNs    CNNs.1    CNNs.2  CNNs.3    CNNs.4    CNNs.5    CNNs.6  \
# ...

# %% [markdown]
# ## Replace non-confident 0 and 1 DFs Nan with Average from training and additional non-confident 0 and 1s

# %%
non_confident_train_df = train_df[~train_df['ID'].isin(confident_ids)]
non_confident_add_0_df = non_confident_train_df[(non_confident_train_df.prediction == 0)]
non_confident_add_1_df = non_confident_train_df[(non_confident_train_df.prediction == 1)]
#display(confident_train_df[:4])
#display(non_confident_train_df[:4])
#display(non_confident_add_0_df[:4])
#display(non_confident_add_1_df[:4])

# %% [markdown]
# # Old

# %%
c_0_df = pd.DataFrame(confident_0_df.drop(['ID','prediction'], axis=1))
c_0_av = confident_0_avg

# %%
c_0_df[:1]
confident_0_df.drop(['ID','prediction'], axis=1)[:4]
confident_0_df
# Out:
#       ID      CNNs    CNNs.1    CNNs.2    CNNs.3    CNNs.4    CNNs.5  \
# 4      5  0.000000  0.285600  0.067485  0.000000  0.441400  0.000000
# 11    12  0.449540  0.027075  0.000000  0.348340  0.000000  0.000000
# 12    13  0.000000  0.000000  0.000000  0.000000  0.382400  0.000000
# 20    21  0.047753  0.429120  0.000000  0.272510  0.078748  0.000000
# 24    25  0.249600  1.342800  0.000000  0.000000  0.803060  0.000000
# 32    33  0.000000  0.017472  0.000000  0.000000  0.000000  0.000000
# 34    35  0.500000  0.126910  0.000000  0.000000  0.158640  0.000000
# 35    36  0.000000  0.000000  0.000000  0.000000  0.000000  0.770570
# 39    40  0.000000  0.000000  0.498700  0.000000  0.315850  0.000000
# 55    56  0.074244  0.165510  1.094200  0.000000  0.114100  0.000000
# 59    60  0.000000  2.120400  0.000000  0.000000  0.000000  0.000000
# 61    62  0.000000  1.317600  0.000000  0.000000  1.033900  0.000000
# 81    82  0.760000  0.718240  0.000000  0.000000  0.775120  0.000000
# ...

# %%
c_0_df = confident_0_df.T[1:-1].T
c_0_av = confident_0_avg
i = 0
for column in c_0_df:
    print(c_0_av[0,column])
    #c_0_df[column] = c_0_av.iloc[0,column].where(c_0_df[column].isnull, c_0_df[column])
    i+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 'CNNs')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
c_0_av.columns.tolist()[:r]
# Out:
# ['CNNs', 'CNNs.1']

# %%
c_0_df[:r]
# Out:
#        CNNs    CNNs.1    CNNs.2   CNNs.3  CNNs.4  CNNs.5   CNNs.6  CNNs.7  \
# 4   0.00000  0.285600  0.067485  0.00000  0.4414     0.0  0.53960     0.0
# 11  0.44954  0.027075  0.000000  0.34834  0.0000     0.0  0.35849     0.0
#
#      CNNs.8  CNNs.9    ...     GIST.502  GIST.503  GIST.504  GIST.505  \
# 4   0.09162     0.0    ...     0.039439  0.014306  0.023978  0.019834
# 11  0.00000     0.0    ...     0.022016  0.011537  0.015376  0.031581
#
#     GIST.506  GIST.507  GIST.508  GIST.509  GIST.510  GIST.511
# 4   0.029528  0.029826  0.027222  0.032496  0.026370  0.028569
# 11  0.016342  0.021201  0.040050  0.029453  0.037315  0.022404
#
# [2 rows x 4608 columns]

# %%
cols = 4608
avg = 0
for i in range(0,4608):
    #print("av")
    avg = c_0_av.ix[:,i]
    #print("df")
    #print(c_0_df.iloc[0:0,i])
    #c_0_df.loc[c_0_df[:,i].isnull()] = avg
    
    c_0_df[c_0_df.columns[i]].fillna(avg)
    #for row in c_0_df[c_0_df.columns[i]]:

# %%
c_0_df
# Out:
#          CNNs    CNNs.1    CNNs.2    CNNs.3    CNNs.4    CNNs.5    CNNs.6  \
# 4    0.000000  0.285600  0.067485  0.000000  0.441400  0.000000  0.539600
# 11   0.449540  0.027075  0.000000  0.348340  0.000000  0.000000  0.358490
# 12   0.000000  0.000000  0.000000  0.000000  0.382400  0.000000  0.000000
# 20   0.047753  0.429120  0.000000  0.272510  0.078748  0.000000  0.000000
# 24   0.249600  1.342800  0.000000  0.000000  0.803060  0.000000  0.000000
# 32   0.000000  0.017472  0.000000  0.000000  0.000000  0.000000  0.000000
# 34   0.500000  0.126910  0.000000  0.000000  0.158640  0.000000  0.227440
# 35   0.000000  0.000000  0.000000  0.000000  0.000000  0.770570  0.000000
# 39   0.000000  0.000000  0.498700  0.000000  0.315850  0.000000  0.103640
# 55   0.074244  0.165510  1.094200  0.000000  0.114100  0.000000  0.000000
# 59   0.000000  2.120400  0.000000  0.000000  0.000000  0.000000  0.000000
# 61   0.000000  1.317600  0.000000  0.000000  1.033900  0.000000  0.000000
# ...
